# %% [markdown]
# # Image Classification Ciffar10 Dataset | Multiple Image Classification CNN | ANN CIFFAR10
#
# In this project, you’ll create an image classification system that can determine the image’s class. Because image classification is such an important application in the field of deep learning, working on this project will allow you to learn about a variety of deep learning topics.
#
# Working on image categorization is one of the finest ways to get started with hands-on deep learning projects for students. CIFAR-10 is a big dataset including approximately 60,000 color images (3232 sizes) divided into ten classes, each with 6,000 images. There are 50,000 photos in the training set and 10,000 images in the test set. The training set will be divided into five portions, each containing 10,000 photos that will be organized in random order. The test set will consist of 1000 photos selected at random from each of the ten classes.

# %% [markdown]
# # Import Tools

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D,BatchNormalization
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %% [markdown]
# # Setting Constant

# %%
batch_size = 32
num_classes = 10
data_augmentation = True

# %% [markdown]
# # The data, shuffled and split between train and test sets:

# %%
# The data, shuffled and split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# # Showing Images

# %%
import matplotlib.pyplot as plt

# Create a figure and axes with the specified number of rows and columns
fig, axes = plt.subplots(2, 3, figsize=(15, 6))

# Flatten the axes array to easily iterate over subplots
axes = axes.flatten()

# Loop through the first ten images in the dataset and plot them
for i in range(2 * 3):
    # Plot the image
    axes[i].imshow(x_train[i])
    axes[i].axis('off')  # Turn off axis labels
    axes[i].set_title(f"Class: {y_train[i]}")

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Feature Scalling

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %% [markdown]
# # Model Architecture

# %%
model = Sequential()

# Convolutional layer with 32 filters, each of size 3x3
model.add(Conv2D(32, (3, 3), kernel_initializer='random_uniform', input_shape=x_train.shape[1:]))
# ReLU activation function
model.add(Activation('relu'))
# Batch normalization layer
model.add(BatchNormalization())

model.add(Conv2D(32, (3, 3), kernel_initializer='random_uniform', input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Conv2D(32, (3, 3), kernel_initializer='random_uniform', input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Conv2D(48, (3, 3), kernel_initializer='random_uniform', input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Conv2D(48, (3, 3), kernel_initializer='random_uniform', input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Conv2D(48, (3, 3), kernel_initializer='random_uniform', input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Conv2D(64, (3, 3), kernel_initializer='random_uniform', input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Conv2D(128, (3, 3), kernel_initializer='random_uniform', input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(BatchNormalization())

# Global max pooling layer
model.add(GlobalMaxPooling2D())
# Dropout layer with dropout rate of 0.25
model.add(Dropout(0.25))

# Fully connected layer with number of units equal to the number of classes
model.add(Dense(num_classes))
# Softmax activation function for multi-class classification
model.add(Activation('softmax'))

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  activation (Activation)     (None, 30, 30, 32)        0
#
#  batch_normalization (Batch  (None, 30, 30, 32)        128
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        9248
#
#  activation_1 (Activation)   (None, 28, 28, 32)        0
#
#  batch_normalization_1 (Bat  (None, 28, 28, 32)        128
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        9248
#
#  activation_2 (Activation)   (None, 26, 26, 32)        0
#
#  batch_normalization_2 (Bat  (None, 26, 26, 32)        128
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 48)        13872
#
#  activation_3 (Activation)   (None, 24, 24, 48)        0
#
#  batch_normalization_3 (Bat  (None, 24, 24, 48)        192
#  chNormalization)
#
#  conv2d_4 (Conv2D)           (None, 22, 22, 48)        20784
#
#  activation_4 (Activation)   (None, 22, 22, 48)        0
#
#  batch_normalization_4 (Bat  (None, 22, 22, 48)        192
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 20, 20, 48)        20784
#
#  activation_5 (Activation)   (None, 20, 20, 48)        0
#
#  batch_normalization_5 (Bat  (None, 20, 20, 48)        192
#  chNormalization)
#
#  conv2d_6 (Conv2D)           (None, 18, 18, 64)        27712
#
#  activation_6 (Activation)   (None, 18, 18, 64)        0
#
#  batch_normalization_6 (Bat  (None, 18, 18, 64)        256
#  chNormalization)
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 128)       73856
#
#  activation_7 (Activation)   (None, 16, 16, 128)       0
#
#  batch_normalization_7 (Bat  (None, 16, 16, 128)       512
#  chNormalization)
#
#  global_max_pooling2d (Glob  (None, 128)               0
#  alMaxPooling2D)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 10)                1290
#
#  activation_8 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 179418 (700.85 KB)
# Trainable params: 178554 (697.48 KB)
# Non-trainable params: 864 (3.38 KB)
# _________________________________________________________________

# %% [markdown]
# # Model Compilation & Training

# %%
opt = keras.optimizers.Adamax(lr=0.001)
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adamax.

# %%
history =model.fit(x_train, y_train,
              batch_size=500,
              epochs=100,
              validation_data=(x_test, y_test),
              shuffle=True)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 22s 102ms/step - loss: 2.7542 - accuracy: 0.2269 - val_loss: 2.3865 - val_accuracy: 0.1000
# Epoch 2/100
# 100/100 [==============================] - 10s 99ms/step - loss: 2.2112 - accuracy: 0.2782 - val_loss: 2.5137 - val_accuracy: 0.1003
# Epoch 3/100
# 100/100 [==============================] - 10s 100ms/step - loss: 2.0177 - accuracy: 0.3222 - val_loss: 2.7578 - val_accuracy: 0.1046
# Epoch 4/100
# 100/100 [==============================] - 10s 101ms/step - loss: 1.8948 - accuracy: 0.3546 - val_loss: 2.8670 - val_accuracy: 0.1525
# Epoch 5/100
# 100/100 [==============================] - 10s 102ms/step - loss: 1.7952 - accuracy: 0.3850 - val_loss: 2.3529 - val_accuracy: 0.2192
# Epoch 6/100
# 100/100 [==============================] - 10s 103ms/step - loss: 1.7096 - accuracy: 0.4118 - val_loss: 1.9665 - val_accuracy: 0.2983
# Epoch 7/100
# 100/100 [==============================] - 11s 106ms/step - loss: 1.6284 - accuracy: 0.4362 - val_loss: 1.5547 - val_accuracy: 0.4489
# Epoch 8/100
# 100/100 [==============================] - 10s 105ms/step - loss: 1.5602 - accuracy: 0.4593 - val_loss: 1.4277 - val_accuracy: 0.5001
# Epoch 9/100
# 100/100 [==============================] - 10s 105ms/step - loss: 1.4962 - accuracy: 0.4800 - val_loss: 1.2908 - val_accuracy: 0.5386
# Epoch 10/100
# 100/100 [==============================] - 10s 102ms/step - loss: 1.4245 - accuracy: 0.5045 - val_loss: 1.3188 - val_accuracy: 0.5247
# Epoch 11/100
# 100/100 [==============================] - 11s 105ms/step - loss: 1.3624 - accuracy: 0.5283 - val_loss: 1.2937 - val_accuracy: 0.5505
# Epoch 12/100
# 100/100 [==============================] - 11s 109ms/step - loss: 1.3069 - accuracy: 0.5452 - val_loss: 1.2452 - val_accuracy: 0.5584
# Epoch 13/100
# 100/100 [==============================] - 11s 110ms/step - loss: 1.2574 - accuracy: 0.5612 - val_loss: 1.2437 - val_accuracy: 0.5631
# Epoch 14/100
# 100/100 [==============================] - 10s 105ms/step - loss: 1.1980 - accuracy: 0.5827 - val_loss: 1.1196 - val_accuracy: 0.6062
# Epoch 15/100
# 100/100 [==============================] - 10s 103ms/step - loss: 1.1429 - accuracy: 0.5984 - val_loss: 1.2222 - val_accuracy: 0.5739
# Epoch 16/100
# 100/100 [==============================] - 10s 105ms/step - loss: 1.1010 - accuracy: 0.6132 - val_loss: 1.0394 - val_accuracy: 0.6320
# Epoch 17/100
# 100/100 [==============================] - 10s 105ms/step - loss: 1.0538 - accuracy: 0.6272 - val_loss: 0.9881 - val_accuracy: 0.6503
# Epoch 18/100
# 100/100 [==============================] - 10s 103ms/step - loss: 1.0135 - accuracy: 0.6455 - val_loss: 1.0694 - val_accuracy: 0.6208
# Epoch 19/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.9848 - accuracy: 0.6559 - val_loss: 0.9763 - val_accuracy: 0.6523
# Epoch 20/100
# 100/100 [==============================] - 10s 105ms/step - loss: 0.9446 - accuracy: 0.6689 - val_loss: 0.9381 - val_accuracy: 0.6714
# Epoch 21/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.9088 - accuracy: 0.6820 - val_loss: 1.0204 - val_accuracy: 0.6387
# Epoch 22/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.8846 - accuracy: 0.6875 - val_loss: 0.9362 - val_accuracy: 0.6717
# Epoch 23/100
# 100/100 [==============================] - 10s 105ms/step - loss: 0.8589 - accuracy: 0.6978 - val_loss: 0.8921 - val_accuracy: 0.6863
# Epoch 24/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.8270 - accuracy: 0.7110 - val_loss: 0.8922 - val_accuracy: 0.6884
# Epoch 25/100
# 100/100 [==============================] - 10s 105ms/step - loss: 0.7963 - accuracy: 0.7210 - val_loss: 0.8441 - val_accuracy: 0.7024
# Epoch 26/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.7713 - accuracy: 0.7304 - val_loss: 0.8378 - val_accuracy: 0.7044
# Epoch 27/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.7473 - accuracy: 0.7367 - val_loss: 0.8737 - val_accuracy: 0.6981
# Epoch 28/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.7298 - accuracy: 0.7446 - val_loss: 0.8490 - val_accuracy: 0.7099
# Epoch 29/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.7089 - accuracy: 0.7515 - val_loss: 0.8630 - val_accuracy: 0.7036
# Epoch 30/100
# 100/100 [==============================] - 10s 105ms/step - loss: 0.6854 - accuracy: 0.7583 - val_loss: 0.9829 - val_accuracy: 0.6638
# Epoch 31/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.6692 - accuracy: 0.7651 - val_loss: 0.9374 - val_accuracy: 0.6790
# Epoch 32/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.6461 - accuracy: 0.7716 - val_loss: 0.8224 - val_accuracy: 0.7166
# Epoch 33/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.6381 - accuracy: 0.7754 - val_loss: 0.7993 - val_accuracy: 0.7300
# Epoch 34/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.6172 - accuracy: 0.7854 - val_loss: 0.8114 - val_accuracy: 0.7166
# Epoch 35/100
# 100/100 [==============================] - 10s 102ms/step - loss: 0.5975 - accuracy: 0.7897 - val_loss: 0.8180 - val_accuracy: 0.7163
# Epoch 36/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.5767 - accuracy: 0.7984 - val_loss: 0.8295 - val_accuracy: 0.7174
# Epoch 37/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.5684 - accuracy: 0.8001 - val_loss: 0.7913 - val_accuracy: 0.7280
# Epoch 38/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.5527 - accuracy: 0.8052 - val_loss: 0.7997 - val_accuracy: 0.7296
# Epoch 39/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.5329 - accuracy: 0.8122 - val_loss: 0.8097 - val_accuracy: 0.7321
# Epoch 40/100
# 100/100 [==============================] - 10s 105ms/step - loss: 0.5262 - accuracy: 0.8156 - val_loss: 0.8309 - val_accuracy: 0.7241
# Epoch 41/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.5093 - accuracy: 0.8210 - val_loss: 0.8233 - val_accuracy: 0.7270
# Epoch 42/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.5004 - accuracy: 0.8248 - val_loss: 0.8192 - val_accuracy: 0.7318
# Epoch 43/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.4801 - accuracy: 0.8305 - val_loss: 0.8316 - val_accuracy: 0.7313
# Epoch 44/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.4670 - accuracy: 0.8380 - val_loss: 0.7893 - val_accuracy: 0.7437
# Epoch 45/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.4585 - accuracy: 0.8393 - val_loss: 0.8527 - val_accuracy: 0.7333
# Epoch 46/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.4410 - accuracy: 0.8463 - val_loss: 0.8763 - val_accuracy: 0.7331
# Epoch 47/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.4325 - accuracy: 0.8461 - val_loss: 0.8318 - val_accuracy: 0.7350
# Epoch 48/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.4168 - accuracy: 0.8517 - val_loss: 0.8528 - val_accuracy: 0.7382
# Epoch 49/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.4107 - accuracy: 0.8536 - val_loss: 0.8361 - val_accuracy: 0.7378
# Epoch 50/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.3997 - accuracy: 0.8577 - val_loss: 0.8753 - val_accuracy: 0.7386
# Epoch 51/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.3906 - accuracy: 0.8598 - val_loss: 0.9004 - val_accuracy: 0.7307
# Epoch 52/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.3760 - accuracy: 0.8649 - val_loss: 0.8690 - val_accuracy: 0.7346
# Epoch 53/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.3655 - accuracy: 0.8706 - val_loss: 0.8600 - val_accuracy: 0.7400
# Epoch 54/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.3641 - accuracy: 0.8701 - val_loss: 0.8946 - val_accuracy: 0.7324
# Epoch 55/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.3482 - accuracy: 0.8764 - val_loss: 0.8998 - val_accuracy: 0.7404
# Epoch 56/100
# 100/100 [==============================] - 10s 102ms/step - loss: 0.3380 - accuracy: 0.8804 - val_loss: 0.9599 - val_accuracy: 0.7259
# Epoch 57/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.3279 - accuracy: 0.8833 - val_loss: 0.9586 - val_accuracy: 0.7264
# Epoch 58/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.3280 - accuracy: 0.8820 - val_loss: 0.9593 - val_accuracy: 0.7305
# Epoch 59/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.3081 - accuracy: 0.8898 - val_loss: 0.9221 - val_accuracy: 0.7322
# Epoch 60/100
# 100/100 [==============================] - 10s 102ms/step - loss: 0.3147 - accuracy: 0.8883 - val_loss: 0.9790 - val_accuracy: 0.7353
# Epoch 61/100
# 100/100 [==============================] - 10s 102ms/step - loss: 0.3006 - accuracy: 0.8928 - val_loss: 0.9713 - val_accuracy: 0.7379
# Epoch 62/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.2992 - accuracy: 0.8925 - val_loss: 0.9880 - val_accuracy: 0.7361
# Epoch 63/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.2891 - accuracy: 0.8960 - val_loss: 1.0196 - val_accuracy: 0.7321
# Epoch 64/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.2761 - accuracy: 0.9002 - val_loss: 0.9865 - val_accuracy: 0.7328
# Epoch 65/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.2680 - accuracy: 0.9039 - val_loss: 1.0031 - val_accuracy: 0.7318
# Epoch 66/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.2703 - accuracy: 0.9039 - val_loss: 0.9948 - val_accuracy: 0.7384
# Epoch 67/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.2630 - accuracy: 0.9057 - val_loss: 1.0356 - val_accuracy: 0.7365
# Epoch 68/100
# 100/100 [==============================] - 10s 105ms/step - loss: 0.2604 - accuracy: 0.9059 - val_loss: 0.9967 - val_accuracy: 0.7397
# Epoch 69/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.2458 - accuracy: 0.9130 - val_loss: 1.0179 - val_accuracy: 0.7388
# Epoch 70/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.2376 - accuracy: 0.9139 - val_loss: 1.0690 - val_accuracy: 0.7479
# Epoch 71/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.2379 - accuracy: 0.9151 - val_loss: 1.0853 - val_accuracy: 0.7311
# Epoch 72/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.2398 - accuracy: 0.9142 - val_loss: 1.0611 - val_accuracy: 0.7352
# Epoch 73/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.2288 - accuracy: 0.9165 - val_loss: 1.1360 - val_accuracy: 0.7334
# Epoch 74/100
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2197 - accuracy: 0.9212 - val_loss: 1.1436 - val_accuracy: 0.7346
# Epoch 75/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.2312 - accuracy: 0.9170 - val_loss: 1.1138 - val_accuracy: 0.7343
# Epoch 76/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.2217 - accuracy: 0.9191 - val_loss: 1.0841 - val_accuracy: 0.7329
# Epoch 77/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.2185 - accuracy: 0.9203 - val_loss: 1.0971 - val_accuracy: 0.7352
# Epoch 78/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.2046 - accuracy: 0.9255 - val_loss: 1.1445 - val_accuracy: 0.7333
# Epoch 79/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.2038 - accuracy: 0.9275 - val_loss: 1.0985 - val_accuracy: 0.7305
# Epoch 80/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.1973 - accuracy: 0.9291 - val_loss: 1.2215 - val_accuracy: 0.7305
# Epoch 81/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.2004 - accuracy: 0.9276 - val_loss: 1.1432 - val_accuracy: 0.7351
# Epoch 82/100
# 100/100 [==============================] - 10s 102ms/step - loss: 0.1918 - accuracy: 0.9305 - val_loss: 1.1950 - val_accuracy: 0.7314
# Epoch 83/100
# 100/100 [==============================] - 10s 102ms/step - loss: 0.1847 - accuracy: 0.9348 - val_loss: 1.2088 - val_accuracy: 0.7302
# Epoch 84/100
# 100/100 [==============================] - 10s 102ms/step - loss: 0.1903 - accuracy: 0.9318 - val_loss: 1.1620 - val_accuracy: 0.7241
# Epoch 85/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.1821 - accuracy: 0.9355 - val_loss: 1.1606 - val_accuracy: 0.7329
# Epoch 86/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.1791 - accuracy: 0.9348 - val_loss: 1.2865 - val_accuracy: 0.7262
# Epoch 87/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.1717 - accuracy: 0.9381 - val_loss: 1.1937 - val_accuracy: 0.7417
# Epoch 88/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.1789 - accuracy: 0.9360 - val_loss: 1.2030 - val_accuracy: 0.7367
# Epoch 89/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.1773 - accuracy: 0.9353 - val_loss: 1.3451 - val_accuracy: 0.7264
# Epoch 90/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.1695 - accuracy: 0.9404 - val_loss: 1.2155 - val_accuracy: 0.7368
# Epoch 91/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1652 - accuracy: 0.9410 - val_loss: 1.2216 - val_accuracy: 0.7307
# Epoch 92/100
# 100/100 [==============================] - 10s 102ms/step - loss: 0.1645 - accuracy: 0.9409 - val_loss: 1.2044 - val_accuracy: 0.7333
# Epoch 93/100
# 100/100 [==============================] - 10s 102ms/step - loss: 0.1629 - accuracy: 0.9432 - val_loss: 1.2319 - val_accuracy: 0.7325
# Epoch 94/100
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1627 - accuracy: 0.9414 - val_loss: 1.2908 - val_accuracy: 0.7259
# Epoch 95/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.1662 - accuracy: 0.9395 - val_loss: 1.2514 - val_accuracy: 0.7318
# Epoch 96/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.1581 - accuracy: 0.9448 - val_loss: 1.3047 - val_accuracy: 0.7376
# Epoch 97/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.1589 - accuracy: 0.9445 - val_loss: 1.2547 - val_accuracy: 0.7336
# Epoch 98/100
# 100/100 [==============================] - 10s 102ms/step - loss: 0.1553 - accuracy: 0.9433 - val_loss: 1.2705 - val_accuracy: 0.7315
# Epoch 99/100
# 100/100 [==============================] - 10s 102ms/step - loss: 0.1513 - accuracy: 0.9459 - val_loss: 1.3027 - val_accuracy: 0.7276
# Epoch 100/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.1472 - accuracy: 0.9481 - val_loss: 1.2606 - val_accuracy: 0.7374

# %% [markdown]
# # Save the Model

# %%
model.save("cifar10_model.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # Training and Validation Loss

# %%
import seaborn as sb
plt.figure(figsize=(10,6))
sb.set_style("whitegrid")
plt.plot(history.history['accuracy'],color="#E74C3C",marker='o')
plt.plot(history.history['val_accuracy'],color='#641E16',marker='h')
plt.title('Accuracy comparison between Validation and Train Data set',fontsize=15)
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
plt.figure(figsize=(10,6))
sb.set_style("whitegrid")
plt.plot(history.history['loss'],color="#E74C3C",marker='o')
plt.plot(history.history['val_loss'],color='#641E16',marker='h')
plt.title('Loss comparison between Validation and Train Data set',fontsize=15)
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
#predictions on the test data and store them in y_pred
y_pred = model.predict(x_test)
# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
# Plot the confusion matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# 313/313 [==============================] - 2s 5ms/step

# %% [markdown]
# # Classification Report

# %%
# Generate the classification report
from sklearn.metrics import classification_report

class_report = classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1))

# Print the classification report
print("Classification Report:")
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.68      0.80      0.73      1000
#            1       0.87      0.85      0.86      1000
#            2       0.63      0.64      0.64      1000
#            3       0.59      0.57      0.58      1000
#            4       0.68      0.69      0.68      1000
#            5       0.69      0.65      0.67      1000
#            6       0.80      0.78      0.79      1000
#            7       0.77      0.75      0.76      1000
#            8       0.81      0.84      0.83      1000
#            9       0.85      0.81      0.83      1000
#
#     accuracy                           0.74     10000
#    macro avg       0.74      0.74      0.74     10000
# weighted avg       0.74      0.74      0.74     10000

# %% [markdown]
# # Predictive System

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

def predict():
    # Randomly select an index from the test set
    idx = random.randint(0, len(x_test) - 1)

    # Select the image and its corresponding label
    image = x_test[idx]
    actual_label = y_test[idx]

    # Make predictions using the trained model
    predictions = model.predict(np.expand_dims(image, axis=0))
    predicted_label = np.argmax(predictions)

    # Define class names (assuming num_classes is defined)
    class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
                  'dog', 'frog', 'horse', 'ship', 'truck']


    # Display the image
    plt.figure(figsize=(1,1))
    plt.imshow(image)
    plt.axis('off')
    plt.title(f'Actual: {class_names[np.argmax(actual_label)]}, Predicted: {class_names[predicted_label]}')
    plt.show()

# %%
predict()
# Out:
# 1/1 [==============================] - 0s 30ms/step

# %%
predict()
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
predict()
# Out:
# 1/1 [==============================] - 0s 30ms/step
